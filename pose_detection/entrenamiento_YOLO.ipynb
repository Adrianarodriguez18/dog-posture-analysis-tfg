# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load a model
model = YOLO("yolo26s-pose.pt")

# %%
conf_file_path = "/content/drive/MyDrive/Notebooks/pruebas_YOLO/dog-pose/dog-pose.yaml"

# %%
custom_project_path = "/content/drive/MyDrive/Notebooks/pruebas_YOLO/custom_dir"

# %%
# Train the model
results = model.train(data=conf_file_path, epochs=200, imgsz=640, patience=50, project=custom_project_path)
# Out:
# Ultralytics 8.4.59 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# ...
